# %% [markdown]
# <a href="https://colab.research.google.com/github/YuValentin/Image-processing-2021/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from skimage import io

# %% [markdown]
# #Основне завдання

# %%
url_color = "http://3.bp.blogspot.com/_f3d3llNlZKQ/SxrJWGZywvI/AAAAAAAABg0/2rV7MNks1lw/s400/Prova.jpg"
url_gray ="https://onlineimagetools.com/images/examples-onlineimagetools/black-dog-gray-srgb.png"


img_color_BGR = io.imread(url_color)
img_gray = io.imread(url_gray)


cv2_imshow(img_color_BGR) 
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F7E7600E310>
# <PIL.Image.Image image mode=RGBA size=640x427 at 0x7F7E742BF7D0>

# %%
img_color_RGB = cv2.cvtColor(img_color_BGR, cv2.COLOR_BGR2RGB) 
cv2_imshow(img_color_RGB)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F7E7434E090>

# %%
img_color_HSV = cv2.cvtColor(img_color_BGR, cv2.COLOR_BGR2HSV) 
cv2_imshow(img_color_HSV)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F7E742B2BD0>

# %%
#RGB

r = img_color_RGB.copy()
r[:, :, 0] = 0
r[:, :, 1] = 0

g = img_color_RGB.copy()
g[:, :, 0] = 0
g[:, :, 2] = 0

b = img_color_RGB.copy()
b[:, :, 1] = 0
b[:, :, 2] = 0

cv2_imshow( cv2.hconcat( (r,g,b) ) )
# Out:
# <PIL.Image.Image image mode=RGB size=1200x400 at 0x7F7E7431CA10>

# %%
#HSV

h = img_color_HSV.copy()
h[:,:,0]=0
h[:,:,1]=0

s = img_color_HSV.copy()
s[:,:,0]=0
s[:,:,2]=0

v = img_color_HSV.copy()
v[:,:,1]=0
v[:,:,2]=0

cv2_imshow( cv2.hconcat( (h,s,v) ) )
# Out:
# <PIL.Image.Image image mode=RGB size=1200x400 at 0x7F7E742B3A90>

# %%
# Region of interest
ROI_height = int(img_gray.shape[0]/2)
ROI_width = int(img_gray.shape[1]/2)

img_gray_roi = img_gray[0 : ROI_height, 0 : ROI_width]

cv2_imshow( img_gray_roi )
# Out:
# <PIL.Image.Image image mode=RGBA size=320x213 at 0x7F7E742D4490>

# %%
cv2.imwrite("Gray_ROI.png",img_gray_roi)
# Out:
# True

# %% [markdown]
# #Додаткове завдання
